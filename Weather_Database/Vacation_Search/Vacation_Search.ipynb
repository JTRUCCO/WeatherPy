# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Glamsbjerg      DK  55.2724   10.1048     65.64        90
# 1        1            Mayo      US  38.8876  -76.5119     80.94        80
# 2        2  San%20Patricio      US  28.0170  -97.5169     86.54        71
# 3        3        Vanavara      RU  60.3400  102.2797     47.68        87
# 4        4           Bluff      NZ -46.6000  168.3333     47.21        66
#
#    Cloudiness  Wind Speed       Description
# 0          55       10.07     broken clouds
# 1          75        3.44     broken clouds
# 2         100       11.95   overcast clouds
# 3         100        2.98   overcast clouds
# 4          50       21.68  scattered clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("Enter the Minimum tempature for your vacation."))
max_temp = float(input("Enter the Maximum tempature for your vacation."))
# Out:
# Enter the Minimum tempature for your vacation.50
# Enter the Maximum tempature for your vacation.70

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
cities_summery_df = city_data_df.loc[(city_data_df["Max Temp"] >= min_temp) & (city_data_df["Max Temp"] <= max_temp)]
cities_summery_df
# Out:
#      City_ID               City Country      Lat       Lng  Max Temp  \
# 0          0         Glamsbjerg      DK  55.2724   10.1048     65.64
# 5          5             Kodiak      US  57.7900 -152.4072     54.91
# 8          8            Talnakh      RU  69.4865   88.3972     58.21
# 10        10     Puerto%20Ayora      EC  -0.7393  -90.3518     66.54
# 18        18          Busselton      AU -33.6500  115.3333     54.95
# 21        21         Codrington      AU -38.2667  141.9667     50.09
# 24        24        Tuktoyaktuk      CA  69.4541 -133.0374     55.40
# 25        25      Port%20Alfred      ZA -33.5906   26.8910     67.80
# 26        26      East%20London      ZA -33.0153   27.9116     65.01
# 28        28              Ambam      CM   2.3833   11.2833     68.25
# 30        30            Iquique      CL -20.2208  -70.1431     57.24
# 32        32        Yellowknife      CA  62.4560 -114.3525     59.56
# 34        34             Castro      BR -24.7911  -50.0119     50.34
# ...

# %%
# 4a. Determine if there are any empty rows.
cities_summery_df.count()
# Out:
# City_ID        51
# City           51
# Country        50
# Lat            51
# Lng            51
# Max Temp       51
# Humidity       51
# Cloudiness     51
# Wind Speed     51
# Description    51
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
cities_summery_clean_df = cities_summery_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = cities_summery_clean_df[["City", "Country", "Max Temp", "Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Description      Lat       Lng  \
# 0       Glamsbjerg      DK     65.64    broken clouds  55.2724   10.1048
# 5           Kodiak      US     54.91       light rain  57.7900 -152.4072
# 8          Talnakh      RU     58.21       light rain  69.4865   88.3972
# 10  Puerto%20Ayora      EC     66.54    broken clouds  -0.7393  -90.3518
# 18       Busselton      AU     54.95  overcast clouds -33.6500  115.3333
# 21      Codrington      AU     50.09  overcast clouds -38.2667  141.9667
# 24     Tuktoyaktuk      CA     55.40  overcast clouds  69.4541 -133.0374
# 25   Port%20Alfred      ZA     67.80        clear sky -33.5906   26.8910
# 26   East%20London      ZA     65.01        clear sky -33.0153   27.9116
# 28           Ambam      CM     68.25       light rain   2.3833   11.2833
#
#    Hotel Name
# 0
# 5
# 8
# 10
# 18
# 21
# 24
# 25
# 26
# 28

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.

for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    params["location"] = f"{latitude},{longitude}"
   

    # 6e. Make request and retrieve the JSON data from the search. 
   
    hotels = requests.get(base_url, params=params).json()
    
    print(hotels)
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 55.262414, 'lng': 10.1205256}, 'viewport': {'northeast': {'lat': 55.2641216802915, 'lng': 10.1213375302915}, 'southwest': {'lat': 55.2614237197085, 'lng': 10.1186395697085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Kulturhuset CulturArte', 'photos': [{'height': 3480, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115688409086047491621">Balalli da Silveira Magalhaes Degas</a>'], 'photo_reference': 'AeJbb3fmlttDlOm2I6lu0WC4t6ht9hGO4Ksfl-t5JjEiWyZBgfFJCxfawYNHA-nWVWhV8cuqypoZdw0q4z0r5oi-ZQl63r-AO-pRIFsrMxpdSHqPIdAiR-fz2D8sYgiBFMhKtoc8dWMlUG-heCZ-Ga2jrWnF7MpRcOnfOr7gyo0Znz71u-ep', 'width': 4640}], 'place_id': 'ChIJRx5FOpfaTEYRDw26Z4ayjno', 'plus_code': {'compound_code': '746C+X6 Gla
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna(axis="index", how="any")
clean_hotel_df.head(10)
# Out:
#               City Country  Max Temp      Description      Lat       Lng  \
# 0       Glamsbjerg      DK     65.64    broken clouds  55.2724   10.1048
# 5           Kodiak      US     54.91       light rain  57.7900 -152.4072
# 8          Talnakh      RU     58.21       light rain  69.4865   88.3972
# 10  Puerto%20Ayora      EC     66.54    broken clouds  -0.7393  -90.3518
# 18       Busselton      AU     54.95  overcast clouds -33.6500  115.3333
# 21      Codrington      AU     50.09  overcast clouds -38.2667  141.9667
# 24     Tuktoyaktuk      CA     55.40  overcast clouds  69.4541 -133.0374
# 25   Port%20Alfred      ZA     67.80        clear sky -33.5906   26.8910
# 26   East%20London      ZA     65.01        clear sky -33.0153   27.9116
# 28           Ambam      CM     68.25       light rain   2.3833   11.2833
#
#                               Hotel Name
# 0                 Kulturhuset CulturArte
# 5                Best Western Kodiak Inn
# ...

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv" 
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""


# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(markers)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#!jupyter nbextension enable --py gmaps
#!jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok
