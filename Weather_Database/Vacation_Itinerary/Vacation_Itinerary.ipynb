# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID            City Country  Max Temp      Description      Lat  \
# 0        0      Glamsbjerg      DK     65.64    broken clouds  55.2724
# 1        5          Kodiak      US     54.91       light rain  57.7900
# 2        8         Talnakh      RU     58.21       light rain  69.4865
# 3       10  Puerto%20Ayora      EC     66.54    broken clouds  -0.7393
# 4       18       Busselton      AU     54.95  overcast clouds -33.6500
#
#         Lng                 Hotel Name
# 0   10.1048     Kulturhuset CulturArte
# 1 -152.4072    Best Western Kodiak Inn
# 2   88.3972              Talnakh Hotel
# 3  -90.3518  Finch Bay Galapagos Hotel
# 4  115.3333    Observatory Guest House

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp}</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
vacation_start = "Glamsbjerg"
vacation_end = "Talnakh"
city2 = "Ambam"
city3 = "Yellowknife"
city4 = "Arys" 

vacation_start = vacation_df.loc[vacation_df["City"] == vacation_start]
vacation_end = vacation_df.loc[vacation_df["City"] == vacation_end]  
vacation_stop2 = vacation_df.loc[vacation_df["City"] == city2]
vacation_stop3 = vacation_df.loc[vacation_df["City"] == city3] 
vacation_stop4 = vacation_df.loc[vacation_df["City"] == city4]

# %%
vacation_df
# Out:
#     City_ID               City Country  Max Temp              Description  \
# 0         0         Glamsbjerg      DK     65.64            broken clouds
# 1         5             Kodiak      US     54.91               light rain
# 2         8            Talnakh      RU     58.21               light rain
# 3        10     Puerto%20Ayora      EC     66.54            broken clouds
# 4        18          Busselton      AU     54.95          overcast clouds
# 5        21         Codrington      AU     50.09          overcast clouds
# 6        24        Tuktoyaktuk      CA     55.40          overcast clouds
# 7        25      Port%20Alfred      ZA     67.80                clear sky
# 8        26      East%20London      ZA     65.01                clear sky
# 9        28              Ambam      CM     68.25               light rain
# 10       30            Iquique      CL     57.24         scattered clouds
# 11       32        Yellowknife      CA     59.56            broken clouds
# 12       34             Castro      BR     50.34                clear sky
# 13       36             Broome      US     68.70               few clouds
# 14       37               Arys      KZ     68.11                clear sky
# 15       38     Severo-Kurilsk      RU     55.99               light rain
# 16       39           Hermanus      ZA     60.80               few clouds
# 17       42     Port%20Lincoln      AU     56.61         scattered clouds
# 18       43               Chuy      UY     54.66          overcast clouds
# 19       44           Thompson      CA     57.36                clear sky
# 20       48         Bredasdorp      ZA     59.05                clear sky
# 21       51        Swan%20Hill      AU     52.07          overcast clouds
# 22       55              Strai      NO     60.64  light intensity drizzle
# 23       59             Shache      CN     69.71         scattered clouds
# 24       66          Esperance      AU     55.18         scattered clouds
# 25       67             Beloha      MG     64.33                clear sky
# 26       68             Turtas      RU     61.34          overcast clouds
# 27       71             Namibe      AO     61.02         scattered clouds
# 28       74             Koboko      UG     60.35            broken clouds
# 29       78          Kisangani      CD     67.48          overcast clouds
# 30       84     Gornopravdinsk      RU     61.95                clear sky
# 31       86                Leh      IN     60.49         scattered clouds
# 32       90   Port%20Elizabeth      ZA     62.31                clear sky
# 33       91           Cidreira      BR     61.02            broken clouds
# 34       94              Bondo      CD     65.55          overcast clouds
# 35       96              Sembe      CG     68.09               light rain
# 36       99              Kharp      RU     62.47          overcast clouds
# 37      101       Wadi%20Maliz      TN     69.46                clear sky
# 38      103  Mar%20Del%20Plata      AR     53.87                clear sky
# 39      105          Inhambane      MZ     65.25               light rain
# 40      107            Dauriya      RU     66.24          overcast clouds
# 41      110               Kang      BW     50.92                clear sky
# 42      111          Tazovskiy      RU     57.65          overcast clouds
# 43      112               Lasa      IT     51.69                clear sky
# 44      113             Hobart      AU     55.26            broken clouds
# 45      114          The%20Pas      CA     68.02         scattered clouds
# 46      115            Chapais      CA     64.18            broken clouds
# 47      116           Coquimbo      CL     53.33                clear sky
# 48      117          Jamestown      US     69.39                clear sky
# 49      118       Vangaindrano      MG     64.83               light rain
#
#         Lat       Lng                             Hotel Name
# 0   55.2724   10.1048                 Kulturhuset CulturArte
# 1   57.7900 -152.4072                Best Western Kodiak Inn
# 2   69.4865   88.3972                          Talnakh Hotel
# 3   -0.7393  -90.3518              Finch Bay Galapagos Hotel
# 4  -33.6500  115.3333                Observatory Guest House
# 5  -38.2667  141.9667   Codrington Gardens Bed And Breakfast
# 6   69.4541 -133.0374                   End of The Road Ltd.
# 7  -33.5906   26.8910                     The Halyards Hotel
# 8  -33.0153   27.9116                                Tu Casa
# 9    2.3833   11.2833                           Ambam Séjour
# 10 -20.2208  -70.1431            Backpacker`s Hostel Iquique
# 11  62.4560 -114.3525                     The Explorer Hotel
# 12 -24.7911  -50.0119                         CHACARA BAILLY
# 13  42.2506  -75.8330             Chenango Valley State Park
# 14  42.4252   68.7950                             Gostinitsa
# 15  50.6789  156.1250                               Kak Doma
# 16 -34.4187   19.2345             Misty Waves Boutique Hotel
# 17 -34.7333  135.8667                     Port Lincoln Hotel
# 18 -33.6971  -53.4616                      Nuevo Hotel Plaza
# 19  55.7435  -97.8558                        Burntwood Hotel
# 20 -34.5322   20.0403               Bredasdorp Country Manor
# 21 -35.3378  143.5544                   Lazy River Motor Inn
# 22  58.2000    7.9000                               Mosterøy
# 23  38.4167   77.2406                           Delong Hotel
# 24 -33.8667  121.9000                  Hospitality Esperance
# 25 -25.1667   45.0500                                    NaN
# 26  58.9417   69.1325                 Domashnyaya Gostinitsa
# 27 -15.1961   12.1522                 Hotel Chik Chik Namibe
# 28   3.4136   30.9599                         Hotel Diplomat
# 29   0.5167   25.2000                     Grand Ramela Hotel
# 30  60.0500   69.9000                                 Hostel
# 31  34.1667   77.5833                    Hotel Ladakh Greens
# 32 -33.9180   25.5701                 39 On Nile Guest House
# 33 -30.1811  -50.2056                          Hotel Castelo
# 34   3.8146   23.6866                                    NaN
# 35   1.6481   14.5806                                    NaN
# 36  66.8014   65.8081                            Hotel "Sob"
# 37  36.4681    8.5495                               Heremony
# 38 -38.0023  -57.5575               Gran Hotel Mar del Plata
# 39 -23.8650   35.3833                                 Oceano
# 40  49.9333  116.8667                                    NaN
# 41 -23.6752   22.7876                        Kang Ultra Stop
# 42  67.4667   78.7000                              TazHostel
# 43  46.6166   10.7002                  Pension Feldgärtenhof
# 44 -42.8794  147.3294  St Ives Hobart Accommodation Tasmania
# 45  53.8251 -101.2541                            Wescana Inn
# 46  49.7834  -74.8492                         Hôtel Opémiska
# 47 -29.9533  -71.3436                         Hotel San Juan
# 48  42.0970  -79.2353         Hampton Inn & Suites Jamestown
# 49 -23.3500   47.6000                           Hotel Fanilo

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat", "Lng"]].to_numpy()[0]
end = vacation_end[["Lat", "Lng"]].to_numpy()[0]
stop1 = vacation_stop2[["Lat", "Lng"]].to_numpy()[0]
stop2 = vacation_stop3[["Lat", "Lng"]].to_numpy()[0]
stop3 = vacation_stop4[["Lat", "Lng"]].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
travel_route = gmaps.directions_layer(start, end, waypoints=[stop1,stop2,stop3], travel_mode="DRIVING" or "BICYCLING" or "WALKING")
fig.add_layer(travel_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop2, vacation_stop3, vacation_stop4],ignore_index=True)
itinerary_df
# Out:
#    City_ID         City Country  Max Temp    Description      Lat       Lng  \
# 0        0   Glamsbjerg      DK     65.64  broken clouds  55.2724   10.1048
# 1       28        Ambam      CM     68.25     light rain   2.3833   11.2833
# 2       32  Yellowknife      CA     59.56  broken clouds  62.4560 -114.3525
# 3       37         Arys      KZ     68.11      clear sky  42.4252   68.7950
#
#                Hotel Name
# 0  Kulturhuset CulturArte
# 1            Ambam Séjour
# 2      The Explorer Hotel
# 3              Gostinitsa

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp}</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig = gmaps.figure()
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
